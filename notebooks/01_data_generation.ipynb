# %% [markdown]
# # 01 - Data Generation
# Generate synthetic data and inspect basic shapes.

# %%
from src.data_generation import generate_data
generate_data()

# %%
import pandas as pd
from pathlib import Path

root = Path.cwd().parents[0]
raw = root / 'data' / 'raw'
for f in ['transactions.csv', 'support_tickets.csv', 'social_mentions.csv']:
    df = pd.read_csv(raw / f)
    print(f'{f}: {df.shape}')
    display(df.head(2))
