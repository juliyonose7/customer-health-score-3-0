# %% [markdown]
# # 03 - Sentiment
# Run sentiment stage and inspect customer-level sentiment features.

# %%
from src.sentiment import build_customer_sentiment
sent = build_customer_sentiment()
sent.head()

# %%
sent[['sentiment_mean', 'sentiment_recent_mean', 'sentiment_trend']].describe()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.histplot(sent['sentiment_mean'], bins=30, kde=True)
plt.title('Customer Sentiment Mean Distribution')
plt.show()
