# %% [markdown]
# # 04 - Features
# Build RFM and final feature matrix used for modeling.

# %%
from src.preprocessing import build_rfm_base
from src.features import build_features

rfm = build_rfm_base()
features = build_features()
rfm.head()

# %%
features.head()

# %%
features[['recency_days', 'frequency', 'monetary_avg', 'sentiment_mean', 'clv']].describe()
