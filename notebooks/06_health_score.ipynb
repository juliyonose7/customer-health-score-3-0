# %% [markdown]
# # 06 - Health Score
# Build final customer health score and export for BI.

# %%
from src.health_score import build_health_score
from dashboard.power_bi_export import export_for_power_bi

health = build_health_score()
export_path = export_for_power_bi()
print(export_path)
health.head()

# %%
health['health_segment'].value_counts()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
sns.histplot(health['health_score'], bins=30, kde=True)
plt.title('Health Score Distribution')
plt.show()
